# %%
# Written by BEDEZUB-13:12

# Import modules
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Load data in csv from dataset folder
churn_master_df = pd.read_csv('/Users/zubquzaini/Documents/data_analysis/data-analysis-statistical-thinking/dataset/original/customer_data.csv')

# %%
# Copy raw data to new variable for pre-processing
churn_df = churn_master_df.copy()

# %%
# Display first five of data
churn_df.head()
# Out:
#    customerID  gender  SeniorCitizen  tenure  ServiceCount        Contract  \
# 0  7590-VHVEG  Female              0       1             2  Month-to-month
# 1  5575-GNVDE    Male              0      34             4        One year
# 2  3668-QPYBK    Male              0       2             4  Month-to-month
# 3  7795-CFOCW    Male              0      45             4        One year
# 4  9237-HQITU  Female              0       2             2  Month-to-month
#
#   PaperlessBilling  MonthlyCharges  TotalCharges Churn
# 0              Yes           29.85         29.85    No
# 1               No           56.95       1889.50    No
# 2              Yes           53.85        108.15   Yes
# 3               No           42.30       1840.75    No
# 4              Yes           70.70        151.65   Yes

# %%
# Get overview of the data
churn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   tenure            7043 non-null   int64
#  4   ServiceCount      7043 non-null   int64
#  5   Contract          7043 non-null   object
#  6   PaperlessBilling  7043 non-null   object
#  7   MonthlyCharges    7043 non-null   float64
#  8   TotalCharges      7016 non-null   float64
#  9   Churn             7043 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 550.4+ KB

# %%
# Check if the data contain missing values
churn_df.isna().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# tenure               0
# ServiceCount         0
# Contract             0
# PaperlessBilling     0
# MonthlyCharges       0
# TotalCharges        27
# Churn                0
# dtype: int64

# %%
# Detail of the data. Display number of rows and column.
# Display if each attribute have missing values
# Display number of unique value in the data
print("rows   :", churn_df.shape[0])
print("columns:", churn_df.shape[1])
print("\nfeatures:\n", churn_df.isnull().any())
print("\nunique values:\n", churn_df.nunique())
# Out:
# rows   : 7043
# columns: 10
#
# features:
#  customerID          False
# gender              False
# SeniorCitizen       False
# tenure              False
# ServiceCount        False
# Contract            False
# PaperlessBilling    False
# MonthlyCharges      False
# TotalCharges         True
# Churn               False
# dtype: bool
#
# unique values:
#  customerID          7043
# gender                 2
# SeniorCitizen          2
# tenure                73
# ServiceCount           9
# Contract               3
# PaperlessBilling       2
# MonthlyCharges      1585
# TotalCharges        6514
# Churn                  2
# dtype: int64

# %%
# Display data with missing values using isna() function.
# Data of the missing values is specified by any(axis=X): axis=1 (kebawah) for instances, axis=0 (ketepi) for attributes
churn_df[churn_df.isna().any(axis=1)]
# Out:
#       customerID  gender  SeniorCitizen  tenure  ServiceCount        Contract  \
# 431   7781-HVGMK  Female              0      72             7        Two year
# 488   4472-LVYGI  Female              0       0             5        Two year
# 753   3115-CZMZD    Male              0       0             7        Two year
# 936   5709-LVOEQ  Female              0       0             7        Two year
# 1082  4367-NUYAO    Male              0       0             8        Two year
# 1261  4741-WWJQZ  Female              0       2             4  Month-to-month
# 1287  8800-ZKRFW  Female              0      30             8  Month-to-month
# 1340  1371-DWPAZ  Female              0       0             6        Two year
# 1487  5035-PGZXH  Female              0      56             7        One year
# 1846  7369-TRPFD    Male              0      19             7        One year
# 1908  8232-UTFOZ    Male              0      69             7        Two year
# ...

# %%
# Display data where tenure is 0
churn_df[churn_df['tenure']==0]
# Out:
#       customerID  gender  SeniorCitizen  tenure  ServiceCount  Contract  \
# 488   4472-LVYGI  Female              0       0             5  Two year
# 753   3115-CZMZD    Male              0       0             7  Two year
# 936   5709-LVOEQ  Female              0       0             7  Two year
# 1082  4367-NUYAO    Male              0       0             8  Two year
# 1340  1371-DWPAZ  Female              0       0             6  Two year
# 3331  7644-OMVMY    Male              0       0             7  Two year
# 3826  3213-VVOLG    Male              0       0             8  Two year
# 4380  2520-SGTTA  Female              0       0             7  Two year
# 5218  2923-ARZLG    Male              0       0             7  One year
# 6670  4075-WKNIU  Female              0       0             7  Two year
# 6754  2775-SEFEE    Male              0       0             6  Two year
#
#      PaperlessBilling  MonthlyCharges  TotalCharges Churn
# ...

# %%
# Display the descriptive statistics of the TotalCharges
churn_df['TotalCharges'].describe()
# Out:
# count    7016.000000
# mean     2282.589168
# std      2265.506114
# min        18.800000
# 25%       401.925000
# 50%      1397.100000
# 75%      3792.325000
# max      8684.800000
# Name: TotalCharges, dtype: float64

# %%
# Display descriptive stats for each where churn is No
churn_df[churn_df['Churn']=='No'].describe()
# Out:
#        SeniorCitizen       tenure  ServiceCount  MonthlyCharges  TotalCharges
# count    5174.000000  5174.000000   5174.000000     5174.000000   5147.000000
# mean        0.128721    37.569965      5.811751       61.265124   2555.220264
# std         0.334923    24.113777      1.890418       31.092648   2328.034938
# min         0.000000     0.000000      1.000000       18.250000     18.800000
# 25%         0.000000    15.000000      4.000000       25.100000    579.200000
# 50%         0.000000    38.000000      6.000000       64.425000   1685.900000
# 75%         0.000000    61.000000      7.000000       88.400000   4263.725000
# max         1.000000    72.000000      9.000000      118.750000   8672.450000

# %%
plt.figure(figsize=(15,5))
sns.boxplot(x='TotalCharges', y='Churn', data=churn_df)
# Out:
# <AxesSubplot:xlabel='TotalCharges', ylabel='Churn'>

# %% [markdown]
# There is some outlier in Churn="Yes". The values are beyond the maximum.
#
# For Churn="No", the distribute is not normal.

# %%
sns.displot(churn_df['TotalCharges'])

# %% [markdown]
# The distribution is skewed to the right. That is not good, we will try to apply square root to the total charges.

# %%
sns.displot(churn_df['TotalCharges'].apply(np.sqrt))

# %% [markdown]
# Looks much better. Not bad.

# %%
# Fun fun, just nak tahu macam mana bentuk dia kalau kita square instead of square root
sns.displot(churn_df['TotalCharges'].apply(np.square))

# %%
# Display regression plot, trying to see how the regression line fit the model
sns.lmplot(
    x='MonthlyCharges', 
    y='TotalCharges', 
    data=churn_df, 
    fit_reg=True, 
    col='Churn', 
    hue='Churn'
)

# %% [markdown]
# Opsss... we cannot see the regression line!

# %%
sns.lmplot(
    x='MonthlyCharges',
    y='TotalCharges',
    data=churn_df,
    fit_reg=True,
    col='Churn', # Guna untuk split to Yes and No
    hue='Churn',
    line_kws={'color': 'red'}
)

# %% [markdown]
# Much better, tak sure kenapa regression line dia tak intercept dengan Y-axis.
# Maybe ada bug kot.

# %%
churn_df[['TotalCharges', 'MonthlyCharges']].corr()
# Out:
#                 TotalCharges  MonthlyCharges
# TotalCharges        1.000000        0.650964
# MonthlyCharges      0.650964        1.000000

# %% [markdown]
# Good positive correlation between Monthly Charges and Total Charges.

# %%
churn_df[churn_df['Churn']=='No'][['TotalCharges', 'MonthlyCharges']].corr()
# Out:
#                 TotalCharges  MonthlyCharges
# TotalCharges         1.00000         0.75739
# MonthlyCharges       0.75739         1.00000

# %% [markdown]
# We can see a strong positive correlation between MonthlyCharges and TotalCharges for Churn='No'

# %%
# Create new variable, churn_no_df 
# Dalam ni, nak store value yang Churn='No' and TotalCharges not null
churn_no_df = churn_df[(churn_df['Churn'] == 'No') & (churn_df['TotalCharges'].isna() == False)]
churn_no_df.shape[0]
# Out:
# 5147

# %%
# Display dataframe
churn_no_df.isna().any()
# Out:
# customerID          False
# gender              False
# SeniorCitizen       False
# tenure              False
# ServiceCount        False
# Contract            False
# PaperlessBilling    False
# MonthlyCharges      False
# TotalCharges        False
# Churn               False
# dtype: bool

# %%
from scipy import stats # Linear regression pacakage. 

# Create a linear regression model with two variable. 
# MonthlyCharges as independent variable. TotalCharges as dependent variable
# TotalCharges is the target we want to predict
slope, intercept, r_value, p_value, std_err = stats.linregress(churn_no_df['MonthlyCharges'], churn_no_df['TotalCharges'])

# %%
print("slope :", slope)             # Gradient of the regression line
print("intercept:", intercept)      # y-intercept of the regression line
print("r_value:", r_value)          # Correlation coefficient
print("p_value:", p_value)          # Threshold
print("std_err:", std_err)          # One of the beautiful method in statistics. You know what it is :)
print("R-squared", r_value**2)      # Proportion of varience in the dependent variable
# Out:
# slope : 56.73637552696062
# intercept: -922.8160085118097
# r_value: 0.7573902887184033
# p_value: 0.0
# std_err: 0.6819261867835148
# R-squared 0.5736400494449463

# %%
ax = sns.regplot(
    x='MonthlyCharges', 
    y='TotalCharges', 
    data=churn_no_df, 
    line_kws={
        'color':'red',
        'label':'y={0:.1f}x+{1:.1f}'.format(slope, intercept)
    })
ax.legend(loc='best')

# %%
sns.lmplot(
    x='tenure', 
    y='TotalCharges', 
    data=churn_df, 
    fit_reg=True,
    line_kws={'color':'red'})

# %%
sns.lmplot(
    x='tenure', 
    y='TotalCharges', 
    data=churn_df, 
    fit_reg=True,
    col='Churn',
    hue='Churn',
    line_kws={'color':'red'})

# %%
churn_df[['TotalCharges', 'tenure']].corr()
# Out:
#               TotalCharges    tenure
# TotalCharges      1.000000  0.826066
# tenure            0.826066  1.000000

# %%
churn_df[churn_df['Churn']=='No'][['TotalCharges', 'tenure']].corr()
# Out:
#               TotalCharges    tenure
# TotalCharges      1.000000  0.793288
# tenure            0.793288  1.000000

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(churn_no_df['tenure'], churn_no_df['TotalCharges'])

# %%
print("slope :", slope)             # Gradient of the regression line
print("intercept:", intercept)      # y-intercept of the regression line
print("r_value:", r_value)          # Correlation coefficient
print("p_value:", p_value)          # Threshold
print("std_err:", std_err)          # One of the beautiful method in statistics. You know what it is :)
print("R-squared", r_value**2)      # Proportion of varience in the dependent variable
# Out:
# slope : 76.74259761920021
# intercept: -334.08560506046933
# r_value: 0.793287728023258
# p_value: 0.0
# std_err: 0.8211475250987232
# R-squared 0.6293054194323026

# %%
ax = sns.regplot(
    x='tenure', 
    y='TotalCharges', 
    data=churn_no_df, 
    line_kws={
        'color':'red',
        'label':'y={0:.1f}x+{1:.1f}'.format(slope, intercept)
    })
ax.legend(loc='best')

# %%
# TODO: Fix this warning
churn_no_df['tenure_charges'] = churn_no_df['tenure'] * churn_no_df['MonthlyCharges']
# Out:
# /var/folders/d7/vdz_56c56fv35pg9gkn51ch00000gn/T/ipykernel_5300/444266630.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   churn_no_df['tenure_charges'] = churn_no_df['tenure'] * churn_no_df['MonthlyCharges']

# %%
churn_no_df.head()
# Out:
#    customerID  gender  SeniorCitizen  tenure  ServiceCount        Contract  \
# 0  7590-VHVEG  Female              0       1             2  Month-to-month
# 1  5575-GNVDE    Male              0      34             4        One year
# 3  7795-CFOCW    Male              0      45             4        One year
# 6  1452-KIOVK    Male              0      22             5  Month-to-month
# 7  6713-OKOMC  Female              0      10             2  Month-to-month
#
#   PaperlessBilling  MonthlyCharges  TotalCharges Churn  tenure_charges
# 0              Yes           29.85         29.85    No           29.85
# 1               No           56.95       1889.50    No         1936.30
# 3               No           42.30       1840.75    No         1903.50
# 6              Yes           89.10       1949.40    No         1960.20
# 7               No           29.75        301.90    No          297.50

# %%
churn_no_df[churn_no_df['Churn']=='No'][['TotalCharges', 'tenure_charges']].corr()
# Out:
#                 TotalCharges  tenure_charges
# TotalCharges        1.000000        0.999535
# tenure_charges      0.999535        1.000000

# %%
sns.lmplot(
    x='tenure_charges',
    y='TotalCharges',
    data=churn_no_df,
    line_kws={'color':'red'}
)

# %%
slope, intercept, r_value, p_value, std_err=stats.linregress(churn_no_df['tenure_charges'], churn_no_df['TotalCharges'])

# %%
print("slope :", slope)             # Gradient of the regression line
print("intercept:", intercept)      # y-intercept of the regression line
print("r_value:", r_value)          # Correlation coefficient
print("p_value:", p_value)          # Threshold
print("std_err:", std_err)          # One of the beautiful method in statistics. You know what it is :)
print("R-squared", r_value**2)
# Out:
# slope : 1.0001720821518205
# intercept: -0.3010983695039613
# r_value: 0.9995350350972924
# p_value: 0.0
# std_err: 0.00042536192429779864
# R-squared 0.9990702863869455

# %%
def fillna(tenure, monthlycharge):
    if tenure == 0:
        totcharges = monthlycharge
    else:
        totcharges = tenure * monthlycharge
        totcharges = intercept + (totcharges * slope)
    return round(totcharges, 2)

# %%
churn_df['TotChargeNew'] = churn_df.apply(lambda x: x['TotalCharges'] if not pd.isna(x['TotalCharges']) else fillna(x['tenure'], x['MonthlyCharges']), axis=1)

# %%
churn_df[churn_df.isna().any(axis=1)]
# Out:
#       customerID  gender  SeniorCitizen  tenure  ServiceCount        Contract  \
# 431   7781-HVGMK  Female              0      72             7        Two year
# 488   4472-LVYGI  Female              0       0             5        Two year
# 753   3115-CZMZD    Male              0       0             7        Two year
# 936   5709-LVOEQ  Female              0       0             7        Two year
# 1082  4367-NUYAO    Male              0       0             8        Two year
# 1261  4741-WWJQZ  Female              0       2             4  Month-to-month
# 1287  8800-ZKRFW  Female              0      30             8  Month-to-month
# 1340  1371-DWPAZ  Female              0       0             6        Two year
# 1487  5035-PGZXH  Female              0      56             7        One year
# 1846  7369-TRPFD    Male              0      19             7        One year
# 1908  8232-UTFOZ    Male              0      69             7        Two year
# ...

# %%
churn_actual_df = pd.read_csv('https://raw.githubusercontent.com/srivatsan88/YouTubeLI/master/dataset/churn_data_actual.csv')

# %%
churn_master_df.head()
# Out:
#    customerID  gender  SeniorCitizen  tenure  ServiceCount        Contract  \
# 0  7590-VHVEG  Female              0       1             2  Month-to-month
# 1  5575-GNVDE    Male              0      34             4        One year
# 2  3668-QPYBK    Male              0       2             4  Month-to-month
# 3  7795-CFOCW    Male              0      45             4        One year
# 4  9237-HQITU  Female              0       2             2  Month-to-month
#
#   PaperlessBilling  MonthlyCharges  TotalCharges Churn
# 0              Yes           29.85         29.85    No
# 1               No           56.95       1889.50    No
# 2              Yes           53.85        108.15   Yes
# 3               No           42.30       1840.75    No
# 4              Yes           70.70        151.65   Yes

# %%
churn_merge = pd.merge(churn_df, churn_actual_df)

# %%
churn_merge[churn_merge.isna().any(axis=1)]
# Out:
#       customerID  gender  SeniorCitizen  tenure  ServiceCount        Contract  \
# 431   7781-HVGMK  Female              0      72             7        Two year
# 488   4472-LVYGI  Female              0       0             5        Two year
# 753   3115-CZMZD    Male              0       0             7        Two year
# 936   5709-LVOEQ  Female              0       0             7        Two year
# 1082  4367-NUYAO    Male              0       0             8        Two year
# 1261  4741-WWJQZ  Female              0       2             4  Month-to-month
# 1287  8800-ZKRFW  Female              0      30             8  Month-to-month
# 1340  1371-DWPAZ  Female              0       0             6        Two year
# 1487  5035-PGZXH  Female              0      56             7        One year
# 1846  7369-TRPFD    Male              0      19             7        One year
# 1908  8232-UTFOZ    Male              0      69             7        Two year
# ...
